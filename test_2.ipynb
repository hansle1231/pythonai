# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data_=pd.read_csv(r'E:\ai\표준협회 수업자료\default-of-credit-card-clients-dataset\UCI_Credit_Card.csv')

# %%
data_=data_.iloc[:,1:]

# %%
data=(data_-np.min(data_,0))/(np.max(data_,0)-np.min(data_,0))

# %%
train_label=data.iloc[:int(0.7*len(data)),-1]
train_data=data.iloc[:int(0.7*len(data)),:-1]
test_label=data.iloc[int(0.7*len(data)):,-1]
test_data=data.iloc[int(0.7*len(data)):,:-1]

# %%
from sklearn.svm import SVC

# %%
train_data
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE       AGE  PAY_0  PAY_2  PAY_3  \
# 0       0.010101  1.0   0.333333  0.333333  0.051724    0.4    0.4    0.1
# 1       0.111111  1.0   0.333333  0.666667  0.086207    0.1    0.4    0.2
# 2       0.080808  1.0   0.333333  0.666667  0.224138    0.2    0.2    0.2
# 3       0.040404  1.0   0.333333  0.333333  0.275862    0.2    0.2    0.2
# 4       0.040404  0.0   0.333333  0.333333  0.620690    0.1    0.2    0.1
# 5       0.040404  0.0   0.166667  0.666667  0.275862    0.2    0.2    0.2
# 6       0.494949  0.0   0.166667  0.666667  0.137931    0.2    0.2    0.2
# 7       0.090909  1.0   0.333333  0.666667  0.034483    0.2    0.1    0.1
# 8       0.131313  1.0   0.500000  0.333333  0.120690    0.2    0.2    0.4
# 9       0.010101  0.0   0.500000  0.666667  0.241379    0.0    0.0    0.0
# 10      0.191919  1.0   0.500000  0.666667  0.224138    0.2    0.2    0.4
# 11      0.252525  1.0   0.166667  0.666667  0.517241    0.1    0.1    0.1
# ...

# %%
for c in [0.1,1,10,100]:
    for gamma in [0.001,0.01,0.1,1,10,100]:
        svc=SVC(C=c,gamma=gamma,random_state=20190730)
        svc.fit(train_data,train_label)
        print('c:{}, gamma:{}, score:{}'.format(c,gamma,svc.score(test_data,test_label)))
# Out:
# c:0.1, gamma:0.001, score:0.7955555555555556
# c:0.1, gamma:0.01, score:0.7955555555555556
# c:0.1, gamma:0.1, score:0.7973333333333333
# c:0.1, gamma:1, score:0.8257777777777778
# c:0.1, gamma:10, score:0.8273333333333334
# c:0.1, gamma:100, score:0.7961111111111111
# c:1, gamma:0.001, score:0.7955555555555556
# c:1, gamma:0.01, score:0.7957777777777778
# c:1, gamma:0.1, score:0.8127777777777778
# c:1, gamma:1, score:0.8341111111111111
# c:1, gamma:10, score:0.8355555555555556
# c:1, gamma:100, score:0.8078888888888889
# c:10, gamma:0.001, score:0.7955555555555556
# c:10, gamma:0.01, score:0.8123333333333334
# c:10, gamma:0.1, score:0.8286666666666667
# c:10, gamma:1, score:0.8368888888888889
# c:10, gamma:10, score:0.8197777777777778
# c:10, gamma:100, score:0.788
# c:100, gamma:0.001, score:0.8118888888888889
# c:100, gamma:0.01, score:0.8133333333333334
# c:100, gamma:0.1, score:0.8362222222222222
# c:100, gamma:1, score:0.8345555555555556
# ...

# %%
test_label
# Out:
# 21000    0
# 21001    1
# 21002    0
# 21003    1
# 21004    1
#         ..
# 29995    0
# 29996    0
# 29997    1
# 29998    1
# 29999    1
# Name: default.payment.next.month, Length: 9000, dtype: int64

# %%
data_.loc[data_.MARRIAGE==0,'MARRIAGE']=3

# %%
ind=(data_.EDUCATION==0)|(data_.EDUCATION==5)|(data_.EDUCATION==6)
data_.loc[ind,'EDUCATION']=4

# %%
data=(data_-np.min(data_,0))/(np.max(data_,0)-np.min(data_,0))
train_data=data.iloc[:int(0.7*len(data)),:-1]
test_data=data.iloc[int(0.7*len(data)):,:-1]

# %%
data.PAY_0.value_counts()
# Out:
# 0    23182
# 1     6817
# Name: PAY_0, dtype: int64

# %%
data_.loc[(data_.PAY_0<=0),'PAY_0']=0
data_.loc[(data_.PAY_0>0),'PAY_0']=1

data_.loc[(data_.PAY_2<=0),'PAY_2']=0
data_.loc[(data_.PAY_2>0),'PAY_2']=1

data_.loc[(data_.PAY_3<=0),'PAY_3']=0
data_.loc[(data_.PAY_3>0),'PAY_3']=1

data_.loc[(data_.PAY_4<=0),'PAY_4']=0
data_.loc[(data_.PAY_4>0),'PAY_4']=1

data_.loc[(data_.PAY_5<=0),'PAY_5']=0
data_.loc[(data_.PAY_5>0),'PAY_5']=1

data_.loc[(data_.PAY_5<=0),'PAY_5']=0
data_.loc[(data_.PAY_5>0),'PAY_5']=1

data_.loc[(data_.PAY_6<=0),'PAY_6']=0
data_.loc[(data_.PAY_6>0),'PAY_6']=1

# %%
data_.PAY_0.value_counts().plot('bar')
# Out:
# C:\Users\Affinity\Anaconda3\envs\keras\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: `Series.plot()` should not be called with positional arguments, only keyword arguments. The order of positional arguments will change in the future. Use `Series.plot(kind='bar')` instead of `Series.plot('bar',)`.
#   """Entry point for launching an IPython kernel.

# %%
data_.MARRIAGE.value_counts().plot('bar')
# Out:
# C:\Users\Affinity\Anaconda3\envs\keras\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: `Series.plot()` should not be called with positional arguments, only keyword arguments. The order of positional arguments will change in the future. Use `Series.plot(kind='bar')` instead of `Series.plot('bar',)`.
#   """Entry point for launching an IPython kernel.

# %%
data_.loc[data_.PAY_0 > 0, 'PAY_0'] = 1
data_.loc[data_.PAY_2 > 0, 'PAY_2'] = 1
data_.loc[data_.PAY_3 > 0, 'PAY_3'] = 1
data_.loc[data_.PAY_4 > 0, 'PAY_4'] = 1
data_.loc[data_.PAY_5 > 0, 'PAY_5'] = 1
data_.loc[data_.PAY_6 > 0, 'PAY_6'] = 1

# %%
data_.EDUCATION.value_counts().plot('bar')
# Out:
# C:\Users\Affinity\Anaconda3\envs\keras\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: `Series.plot()` should not be called with positional arguments, only keyword arguments. The order of positional arguments will change in the future. Use `Series.plot(kind='bar')` instead of `Series.plot('bar',)`.
#   """Entry point for launching an IPython kernel.

# %%
data_.loc[(data_['AGE']>=20)&(data_['AGE']<30),'AGE']=1
data_.loc[(data_.AGE>=30)&(data_.AGE<40)]=2
data_.loc[(data_.AGE>=40)&(data_.AGE<50)]=3
data_.loc[(data_.AGE>=50)&(data_.AGE<60)]=4
data_.loc[(data_.AGE>=60)&(data_.AGE<70)]=5
data_.loc[(data_.AGE>=70)&(data_.AGE<80)]=6

# %%
from sklearn.svm import SVC

svc=SVC()

# %%
data=data_

# %%
len(data)*0.7
# Out:
# 21000.0

# %%
from sklearn.svm import SVC

# %%
train_label
# Out:
# 0        0.166667
# 1        0.166667
# 2        0.333333
# 3        0.333333
# 4        0.666667
#            ...
# 20995    0.500000
# 20996    0.333333
# 20997    0.333333
# 20998    0.333333
# 20999    0.500000
# Name: default.payment.next.month, Length: 21000, dtype: float64

# %%
svm=SVC(random_state=20190730,probability=True)
svm.fit(train_data,train_label)
# Out:
# C:\Users\Affinity\Anaconda3\envs\keras\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=True, random_state=20190730,
#     shrinking=True, tol=0.001, verbose=False)

# %%
svm.score(test_data,test_label)
# Out:
# 0.7955555555555556

# %%
data_

# %%
probs_=svm.predict_proba(test_data)

# %%
pd.DataFrame(probs,columns=['0일확률','1일확률'])
# Out:
#           0일확률      1일확률
# 0     0.768474  0.231526
# 1     0.631346  0.368654
# 2     0.801771  0.198229
# 3     0.658371  0.341629
# 4     0.612925  0.387075
# ...        ...       ...
# 8995  0.805771  0.194229
# 8996  0.882993  0.117007
# 8997  0.217160  0.782840
# 8998  0.776800  0.223200
# 8999  0.799758  0.200242
#
# [9000 rows x 2 columns]

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# %%
fpr,tpr,threshold=roc_curve(test_label,probs)

# %%
probs=probs_[:,1]

# %%
auc=roc_auc_score(test_label,probs)

# %%
auc
# Out:
# 0.719343765180957

# %%
data.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default.payment.next.month'],
#       dtype='object')

# %%
data.BILL_AMT1.hist()

# %%
data.loc[:,['PAY_AMT1','default.payment.next.month']]
# Out:
#        PAY_AMT1  default.payment.next.month
# 1           0.0                           1
# 2        1518.0                           0
# 3        2000.0                           0
# 4        2000.0                           0
# 5        2500.0                           0
# ...         ...                         ...
# 29995    8500.0                           0
# 29996    1837.0                           0
# 29997       0.0                           1
# 29998   85900.0                           1
# 29999    2078.0                           1
#
# [29999 rows x 2 columns]

# %%
fpr
# Out:
# array([0.        , 0.        , 0.        , ..., 0.99902235, 0.99902235,
#        1.        ])

# %%
plt.plot(fpr,tpr)
plt.plot([1,0],[1,0],color='black',linestyle='--')

# %%
for c in [0.001,0.01,0.1,1,10,100]:
    for gamma in [0.001,0.01,0.1,1,10,100]:
        svc=SVC(C=c,gamma=gamma,random_state=20190730)
        svc.fit(train_data,train_label)
        print('c:{}, gamma:{}, score:{}'.format(c,gamma,svc.score(test_data,test_label)))
# Out:
# c:0.001, gamma:0.001, score:0.7955555555555556
# c:0.001, gamma:0.01, score:0.7955555555555556
# c:0.001, gamma:0.1, score:0.7955555555555556
# c:0.001, gamma:1, score:0.7955555555555556
# c:0.001, gamma:10, score:0.7955555555555556
# c:0.001, gamma:100, score:0.7955555555555556
# c:0.01, gamma:0.001, score:0.7955555555555556
# c:0.01, gamma:0.01, score:0.7955555555555556
# c:0.01, gamma:0.1, score:0.7955555555555556
# c:0.01, gamma:1, score:0.7955555555555556
# c:0.01, gamma:10, score:0.7955555555555556
# c:0.01, gamma:100, score:0.7955555555555556
# c:0.1, gamma:0.001, score:0.7955555555555556
# c:0.1, gamma:0.01, score:0.7955555555555556
# c:0.1, gamma:0.1, score:0.7955555555555556
# c:0.1, gamma:1, score:0.7955555555555556
# c:0.1, gamma:10, score:0.7982222222222223
# c:0.1, gamma:100, score:0.7955555555555556
# c:1, gamma:0.001, score:0.7955555555555556
# c:1, gamma:0.01, score:0.7955555555555556
# c:1, gamma:0.1, score:0.7955555555555556
# c:1, gamma:1, score:0.8
# ...

# %%
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE       AGE  PAY_0  PAY_2  PAY_3  \
# 0       0.010101  1.0   0.333333       0.0  0.051724  0.250   0.25   0.00
# 1       0.111111  1.0   0.333333       0.5  0.086207  0.000   0.25   0.00
# 2       0.080808  1.0   0.333333       0.5  0.224138  0.000   0.00   0.00
# 3       0.040404  1.0   0.333333       0.0  0.275862  0.000   0.00   0.00
# 4       0.040404  0.0   0.333333       0.0  0.620690  0.000   0.00   0.00
# ...          ...  ...        ...       ...       ...    ...    ...    ...
# 20995   0.040404  0.0   0.333333       0.0  0.482759  0.125   0.25   0.25
# 20996   0.222222  0.0   0.333333       0.5  0.293103  0.250   0.25   0.25
# 20997   0.070707  0.0   0.333333       0.0  0.293103  0.000   0.00   0.00
# 20998   0.191919  0.0   0.333333       0.0  0.189655  0.000   0.00   0.00
# 20999   0.040404  0.0   0.666667       0.0  0.327586  0.000   0.00   0.00
#
#        PAY_4  PAY_5  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  \
# ...

# %%
svc=SVC(C=100,gamma=0.1,random_state=20190730,tol=0.001)
svc.fit(train_data,train_label)
# Out:
# SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.1, kernel='rbf',
#     max_iter=-1, probability=False, random_state=20190730, shrinking=True,
#     tol=0.001, verbose=False)

# %%
svc.score(test_data,test_label)
# Out:
# 0.8341111111111111

# %%
train_data
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE       AGE  PAY_0  PAY_2  PAY_3  \
# 0       0.010101  1.0   0.333333  0.333333  0.051724    0.4    0.4    0.1
# 1       0.111111  1.0   0.333333  0.666667  0.086207    0.1    0.4    0.2
# 2       0.080808  1.0   0.333333  0.666667  0.224138    0.2    0.2    0.2
# 3       0.040404  1.0   0.333333  0.333333  0.275862    0.2    0.2    0.2
# 4       0.040404  0.0   0.333333  0.333333  0.620690    0.1    0.2    0.1
# ...          ...  ...        ...       ...       ...    ...    ...    ...
# 20995   0.040404  0.0   0.333333  0.333333  0.482759    0.3    0.4    0.4
# 20996   0.222222  0.0   0.333333  0.666667  0.293103    0.4    0.4    0.4
# 20997   0.070707  0.0   0.333333  0.333333  0.293103    0.2    0.2    0.2
# 20998   0.191919  0.0   0.333333  0.333333  0.189655    0.1    0.1    0.2
# 20999   0.040404  0.0   0.500000  0.333333  0.327586    0.1    0.1    0.1
#
#        PAY_4  PAY_5  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  \
# ...
