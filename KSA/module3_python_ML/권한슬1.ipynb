# %%
from md import *

# %%
data=pd.read_csv('LOG_DATA.csv')

# %%
data
# Out:
#        MASTERLOG_ID           MSG_DATETIME  MSG_STATUS  HUB_CNT  SPOKE_CNT  \
# 0                19  20181101000125600000            0        0          1
# 1                19  20181101000143000000            0        0          1
# 2                19  20181101000144700000            0        0          1
# 3                19  20181101000241200000            0        0          1
# 4                19  20181101000248600000            0        0          1
# 5                19  20181101000817200000            0        0          1
# 6                19  20181101000823300000            0        0          1
# 7                19  20181101000955200000            0        0          1
# 8                19  20181101001403800000            0        0          1
# 9                19  20181101001528400000            0        0          1
# 10               19  20181101001618400000            0        0          1
# ...

# %%
data['P_TIME']
# Out:
# 0        00:01.8
# 1        00:08.1
# 2        00:17.3
# 3        00:06.8
# 4        00:10.4
# 5        00:06.2
# 6        00:11.0
# 7        00:13.9
# 8        00:09.7
# 9        00:08.9
# 10       00:14.0
# 11       00:08.1
# 12       00:11.1
# 13       00:10.7
# 14       00:06.6
# 15       00:17.5
# 16       00:13.5
# 17       00:10.7
# 18       00:11.8
# 19       00:01.6
# 20       00:13.4
# 21       00:09.1
# 22       00:07.8
# 23       00:13.1
# 24       00:10.4
# 25       00:04.7
# 26       00:11.0
# 27       00:13.9
# 28       00:07.3
# 29       00:10.4
#           ...
# 43200    00:08.2
# 43201    00:13.2
# 43202    00:19.8
# 43203    00:20.7
# 43204    00:12.5
# 43205    00:22.0
# 43206    00:19.1
# 43207    00:29.7
# 43208    00:21.8
# 43209    00:02.8
# 43210    00:10.0
# 43211    00:17.7
# 43212    00:10.1
# 43213    00:16.1
# 43214    00:24.2
# 43215    00:18.0
# 43216    00:28.3
# 43217    00:20.8
# 43218    00:19.8
# 43219    00:17.4
# 43220    00:23.1
# ...

# %%
data.columns
# Out:
# Index(['MASTERLOG_ID', 'MSG_DATETIME', 'MSG_STATUS', 'HUB_CNT', 'SPOKE_CNT',
#        'RECV_HUB_CNT', 'RECV_SPOKE_CNT', 'ERROR_TYPE', 'ERROR_CNT',
#        'REASON_CODE', 'MSG_TTL', 'MSG_ALERT', 'RECORD_CNT', 'ADAPTER_CODE',
#        'RECORD_SIZE', 'DATA_SIZE', 'COMPRESS_YN', 'COMPRESS_SIZE',
#        'SOURCE_DIR_NM', 'SOURCE_FILE_NM', 'TARGET_DIR_NM', 'TARGET_FILE_NM',
#        'RECORD_S_CNT', 'RECORD_E_CNT', 'P_TIME', 'GLOBAL_ID', 'RECV_HOST_ID'],
#       dtype='object')

# %%
data['P_TIME'][0].replace('00:','')
# Out:
# '01.8'

# %%
label=pd.DataFrame(np.ones([len(data),1]),columns=['label'])

# %%
labeled_data=pd.concat([label,data],axis=1)

# %%
labeled_data['label']
# Out:
# 0        1.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        1.0
# 5        1.0
# 6        1.0
# 7        1.0
# 8        1.0
# 9        1.0
# 10       1.0
# 11       1.0
# 12       1.0
# 13       1.0
# 14       1.0
# 15       1.0
# 16       1.0
# 17       1.0
# 18       1.0
# 19       1.0
# 20       1.0
# 21       1.0
# 22       1.0
# 23       1.0
# 24       1.0
# 25       1.0
# 26       1.0
# 27       1.0
# 28       1.0
# 29       1.0
#         ...
# 43200    1.0
# 43201    1.0
# 43202    1.0
# 43203    1.0
# 43204    1.0
# 43205    1.0
# 43206    1.0
# 43207    1.0
# 43208    1.0
# 43209    1.0
# 43210    1.0
# 43211    1.0
# 43212    1.0
# 43213    1.0
# 43214    1.0
# 43215    1.0
# 43216    1.0
# 43217    1.0
# 43218    1.0
# 43219    1.0
# 43220    1.0
# 43221    1.0
# 43222    1.0
# 43223    1.0
# 43224    1.0
# 43225    1.0
# 43226    1.0
# 43227    1.0
# 43228    1.0
# 43229    1.0
# Name: label, Length: 43230, dtype: float64

# %%
labeled_data.columns
# Out:
# Index(['label', 'MASTERLOG_ID', 'MSG_DATETIME', 'MSG_STATUS', 'HUB_CNT',
#        'SPOKE_CNT', 'RECV_HUB_CNT', 'RECV_SPOKE_CNT', 'ERROR_TYPE',
#        'ERROR_CNT', 'REASON_CODE', 'MSG_TTL', 'MSG_ALERT', 'RECORD_CNT',
#        'ADAPTER_CODE', 'RECORD_SIZE', 'DATA_SIZE', 'COMPRESS_YN',
#        'COMPRESS_SIZE', 'SOURCE_DIR_NM', 'SOURCE_FILE_NM', 'TARGET_DIR_NM',
#        'TARGET_FILE_NM', 'RECORD_S_CNT', 'RECORD_E_CNT', 'P_TIME', 'GLOBAL_ID',
#        'RECV_HOST_ID'],
#       dtype='object')

# %%
for i in range(len(data)):
    if float(data['P_TIME'][i].replace('00:','')) > 20:
        labeled_data['label'][i]=0
# Out:
# C:\ProgramData\Anaconda3\envs\mp\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
labeled_data[labeled_data['label']==0]
# Out:
#        label  MASTERLOG_ID           MSG_DATETIME  MSG_STATUS  HUB_CNT  \
# 41790    0.0            19  20181130000109100000            0        0
# 41792    0.0            19  20181130000500700000            0        0
# 41793    0.0            19  20181130000621400000            0        0
# 41794    0.0            19  20181130000653700000            0        0
# 41796    0.0            19  20181130000736500000            0        0
# 41798    0.0            19  20181130000938900000            0        0
# 41799    0.0            19  20181130001006400000            0        0
# 41801    0.0            19  20181130001121200000            0        0
# 41802    0.0            19  20181130001132000000            0        0
# 41803    0.0            19  20181130001408200000            0        0
# 41804    0.0            19  20181130001456300000            0        0
# 41805    0.0            19  20181130001500100000            0        0
# ...

# %%
labeled_data
# Out:
#        label  MASTERLOG_ID           MSG_DATETIME  MSG_STATUS  HUB_CNT  \
# 0        1.0            19  20181101000125600000            0        0
# 1        1.0            19  20181101000143000000            0        0
# 2        1.0            19  20181101000144700000            0        0
# 3        1.0            19  20181101000241200000            0        0
# 4        1.0            19  20181101000248600000            0        0
# 5        1.0            19  20181101000817200000            0        0
# 6        1.0            19  20181101000823300000            0        0
# 7        1.0            19  20181101000955200000            0        0
# 8        1.0            19  20181101001403800000            0        0
# 9        1.0            19  20181101001528400000            0        0
# 10       1.0            19  20181101001618400000            0        0
# 11       1.0            19  20181101001624600000            0        0
# ...

# %% [markdown]
# # 2번

# %%
df=labeled_data[['label','MSG_DATETIME','P_TIME']]

# %%
df

# %%
p_time=pd.DataFrame(np.zeros([len(df),1]),columns=['p_time'])

# %%
p_time

# %%
df=pd.concat([df,p_time],axis=1)

# %%
df

# %%
for i in range(len(df)):
  df['p_time'][i]=float(df['P_TIME'][i].replace('00:',''))
# Out:
# C:\ProgramData\Anaconda3\envs\mp\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
df.re
# Out:
#        label           MSG_DATETIME   P_TIME  p_time
# 0        1.0  20181101000125600000   00:01.8     1.8
# 1        1.0  20181101000143000000   00:08.1     8.1
# 2        1.0  20181101000144700000   00:17.3    17.3
# 3        1.0  20181101000241200000   00:06.8     6.8
# 4        1.0  20181101000248600000   00:10.4    10.4
# 5        1.0  20181101000817200000   00:06.2     6.2
# 6        1.0  20181101000823300000   00:11.0    11.0
# 7        1.0  20181101000955200000   00:13.9    13.9
# 8        1.0  20181101001403800000   00:09.7     9.7
# 9        1.0  20181101001528400000   00:08.9     8.9
# 10       1.0  20181101001618400000   00:14.0    14.0
# 11       1.0  20181101001624600000   00:08.1     8.1
# 12       1.0  20181101001642700000   00:11.1    11.1
# 13       1.0  20181101001657100000   00:10.7    10.7
# 14       1.0  20181101002122300000   00:06.6     6.6
# 15       1.0  20181101002351300000   00:17.5    17.5
# 16       1.0  20181101002407400000   00:13.5    13.5
# ...

# %%
df.to_csv('dffff.csv',mode='w')

# %%
df['p_time']=log

# %%
df2=df[['MSG_DATETIME','p_time']]

# %%
time(int(df2['MSG_DATETIME'][0]))
# Out:
# Wall time: 0 ns
# 20181101000125600000

# %%
df
# Out:
#        label           MSG_DATETIME   P_TIME  p_time
# 0        1.0  20181101000125600000   00:01.8     1.8
# 1        1.0  20181101000143000000   00:08.1     8.1
# 2        1.0  20181101000144700000   00:17.3    17.3
# 3        1.0  20181101000241200000   00:06.8     6.8
# 4        1.0  20181101000248600000   00:10.4    10.4
# 5        1.0  20181101000817200000   00:06.2     6.2
# 6        1.0  20181101000823300000   00:11.0    11.0
# 7        1.0  20181101000955200000   00:13.9    13.9
# 8        1.0  20181101001403800000   00:09.7     9.7
# 9        1.0  20181101001528400000   00:08.9     8.9
# 10       1.0  20181101001618400000   00:14.0    14.0
# 11       1.0  20181101001624600000   00:08.1     8.1
# 12       1.0  20181101001642700000   00:11.1    11.1
# 13       1.0  20181101001657100000   00:10.7    10.7
# 14       1.0  20181101002122300000   00:06.6     6.6
# 15       1.0  20181101002351300000   00:17.5    17.5
# 16       1.0  20181101002407400000   00:13.5    13.5
# ...

# %%
q=(df['MSG_DATETIME'][0].replace('00000',''))

# %%
# Out:
# '201811010001256 '
