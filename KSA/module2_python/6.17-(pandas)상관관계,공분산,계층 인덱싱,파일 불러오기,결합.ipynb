# %%
import numpy as np
import pandas as pd 
from pandas import DataFrame, Series

# %% [markdown]
# ### steel.txt=온도(x1)와 압력(x2)에 따른 강도(Y)

# %%
steel_data=np.loadtxt('steel.txt',skiprows=5,delimiter='\t')  #delimiter=구분자

# %%
steel_data
# Out:
# array([[ 81.4, 195. ,  57. ],
#        [122.2, 179. ,  61. ],
#        [101.7, 205. ,  60. ],
#        [175.6, 204. ,  62. ],
#        [150.3, 201. ,  61. ],
#        [ 64.8, 184. ,  54. ],
#        [ 92.1, 210. ,  58. ],
#        [113.8, 209. ,  61. ]])

# %%
df=pd.DataFrame(steel_data,columns=['y','x1','x2'])

# %%
df['x21']=df.x2*10  #x21이라는 칼럼을 새로만들어준다.

# %%
df
# Out:
#        y     x1    x2    x21
# 0   81.4  195.0  57.0  570.0
# 1  122.2  179.0  61.0  610.0
# 2  101.7  205.0  60.0  600.0
# 3  175.6  204.0  62.0  620.0
# 4  150.3  201.0  61.0  610.0
# 5   64.8  184.0  54.0  540.0
# 6   92.1  210.0  58.0  580.0
# 7  113.8  209.0  61.0  610.0

# %% [markdown]
# ## 공분산
#
#
# 두 확률변수의 선형적 관계에 대한 척도
#
# 확률론과 통계학에서, 공분산(共分散, 영어: covariance)은 2개의 확률변수의 상관정도를 나타내는 값이다.(1개의 변수의 이산정도를 나타내는 분산과는 별개임) 만약 2개의 변수중 하나의 값이 상승하는 경향을 보일 때, 다른 값도 상승하는 경향의 상관관계에 있다면, 공분산의 값은 양수가 될 것이다. 반대로 2개의 변수중 하나의 값이 상승하는 경향을 보일 때, 다른 값이 하강하는 경향을 보인다면 공분산의 값은 음수가 된다. 이렇게 공분산은 상관관계의 상승 혹은 하강하는 경향을 이해할 수 있으나 2개 변수의 측정 단위의 크기에 따라 값이 달라지므로 상관분석을 통해 정도를 파악하기에는 부적절하다. 상관분석에서는 상관관계의 정도를 나타내는 단위로 모상관계수 ρ를 사용한다.

# %%
df.x2.cov(df.y)  #x2와 Y의 공분산
# Out:
# 85.24642857142857

# %%
df.cov()  #모든 공분산구해서 행렬로출력  대각선분은 각변수의 분산
# Out:
#                y          x1         x2         x21
# y    1325.868393  108.855357  85.246429  852.464286
# x1    108.855357  131.982143  11.178571  111.785714
# x2     85.246429   11.178571   7.357143   73.571429
# x21   852.464286  111.785714  73.571429  735.714286

# %% [markdown]
# x21의 공분산이 x2의 2배(같은 관계지만 단위가커지니까 공분산도 커진다)

# %% [markdown]
# ### 상관관계

# %%
df.x1.corr(df.y)
# Out:
# 0.2602208017100887

# %%
df.corr()
# Out:
#             y        x1        x2       x21
# y    1.000000  0.260221  0.863120  0.863120
# x1   0.260221  1.000000  0.358735  0.358735
# x2   0.863120  0.358735  1.000000  1.000000
# x21  0.863120  0.358735  1.000000  1.000000

# %%
df.corrwith(df.y)  #y랑 나머지관계
# Out:
# y      1.000000
# x1     0.260221
# x2     0.863120
# x21    0.863120
# dtype: float64

# %%
s=Series([32,43,52,32,43])

# %%
s
# Out:
# 0    32
# 1    43
# 2    52
# 3    32
# 4    43
# dtype: int64

# %%
s.isin([32,52])
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4    False
# dtype: bool

# %%
s.unique()  #중복없앰
# Out:
# array([32, 43, 52], dtype=int64)

# %%
s.value_counts()   #원소갯수 카운트
# Out:
# 43    2
# 32    2
# 52    1
# dtype: int64

# %%
s[s.isin([32,52])]
# Out:
# 0    32
# 2    52
# 3    32
# dtype: int64

# %%
gender=Series(['f','m','m','f','m'])

# %%
gender[gender.isin(['f'])]
# Out:
# 0    f
# 3    f
# dtype: object

# %%
print(gender[gender.isin(['m'])])
print(gender[gender=='f'])
# Out:
# 1    m
# 2    m
# 4    m
# dtype: object
# 0    f
# 3    f
# dtype: object

# %%
data={'dtt':[5,4,4,2],'hw':[7,9,8,6],'mid':[42,42,31,12],'fin':[26,53,26,24]}

# %%
df=DataFrame(data)

# %%
df
# Out:
#    dtt  hw  mid  fin
# 0    5   7   42   26
# 1    4   9   42   53
# 2    4   8   31   26
# 3    2   6   12   24

# %%
df.dtt.unique()
# Out:
# array([5, 4, 2], dtype=int64)

# %%
df.dtt.value_counts() #dtt 원소들 갯수 샘
# Out:
# 4    2
# 2    1
# 5    1
# Name: dtt, dtype: int64

# %%
df.apply(pd.value_counts)  #df 에 pd.value_counts 전부 적용
# Out:
#     dtt   hw  mid  fin
# 2   1.0  NaN  NaN  NaN
# 4   2.0  NaN  NaN  NaN
# 5   1.0  NaN  NaN  NaN
# 6   NaN  1.0  NaN  NaN
# 7   NaN  1.0  NaN  NaN
# 8   NaN  1.0  NaN  NaN
# 9   NaN  1.0  NaN  NaN
# 12  NaN  NaN  1.0  NaN
# 24  NaN  NaN  NaN  1.0
# 26  NaN  NaN  NaN  2.0
# 31  NaN  NaN  1.0  NaN
# 42  NaN  NaN  2.0  NaN
# 53  NaN  NaN  NaN  1.0

# %%
df.apply()

# %% [markdown]
# print 로 출력하면 텍스트로 변경되서 출력해서 정확히파악이안됌

# %%
result=df.apply(pd.value_counts)    #얘도 데이터프레임이라 데이터프레임 매소드전부사용가능

# %%
result.fillna('ㅂㅂㅂ')   #nan값을 ㅂㅂㅂ으로채움
# Out:
#     dtt   hw  mid  fin
# 2     1  ㅂㅂㅂ  ㅂㅂㅂ  ㅂㅂㅂ
# 4     2  ㅂㅂㅂ  ㅂㅂㅂ  ㅂㅂㅂ
# 5     1  ㅂㅂㅂ  ㅂㅂㅂ  ㅂㅂㅂ
# 6   ㅂㅂㅂ    1  ㅂㅂㅂ  ㅂㅂㅂ
# 7   ㅂㅂㅂ    1  ㅂㅂㅂ  ㅂㅂㅂ
# 8   ㅂㅂㅂ    1  ㅂㅂㅂ  ㅂㅂㅂ
# 9   ㅂㅂㅂ    1  ㅂㅂㅂ  ㅂㅂㅂ
# 12  ㅂㅂㅂ  ㅂㅂㅂ    1  ㅂㅂㅂ
# 24  ㅂㅂㅂ  ㅂㅂㅂ  ㅂㅂㅂ    1
# 26  ㅂㅂㅂ  ㅂㅂㅂ  ㅂㅂㅂ    2
# 31  ㅂㅂㅂ  ㅂㅂㅂ    1  ㅂㅂㅂ
# 42  ㅂㅂㅂ  ㅂㅂㅂ    2  ㅂㅂㅂ
# 53  ㅂㅂㅂ  ㅂㅂㅂ  ㅂㅂㅂ    1

# %%
result.fillna('ㅂㅂㅂ')[result.fillna('ㅂㅂㅂ')=='ㅂㅂㅂ']
# Out:
#     dtt   hw  mid  fin
# 2   NaN  ㅂㅂㅂ  ㅂㅂㅂ  ㅂㅂㅂ
# 4   NaN  ㅂㅂㅂ  ㅂㅂㅂ  ㅂㅂㅂ
# 5   NaN  ㅂㅂㅂ  ㅂㅂㅂ  ㅂㅂㅂ
# 6   ㅂㅂㅂ  NaN  ㅂㅂㅂ  ㅂㅂㅂ
# 7   ㅂㅂㅂ  NaN  ㅂㅂㅂ  ㅂㅂㅂ
# 8   ㅂㅂㅂ  NaN  ㅂㅂㅂ  ㅂㅂㅂ
# 9   ㅂㅂㅂ  NaN  ㅂㅂㅂ  ㅂㅂㅂ
# 12  ㅂㅂㅂ  ㅂㅂㅂ  NaN  ㅂㅂㅂ
# 24  ㅂㅂㅂ  ㅂㅂㅂ  ㅂㅂㅂ  NaN
# 26  ㅂㅂㅂ  ㅂㅂㅂ  ㅂㅂㅂ  NaN
# 31  ㅂㅂㅂ  ㅂㅂㅂ  NaN  ㅂㅂㅂ
# 42  ㅂㅂㅂ  ㅂㅂㅂ  NaN  ㅂㅂㅂ
# 53  ㅂㅂㅂ  ㅂㅂㅂ  ㅂㅂㅂ  NaN

# %%
s=Series(['kim',np.nan,'lee',None,'cho','kang'])

# %%
s.isnull()  #null이 있느냐
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# dtype: bool

# %%
s.isna()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# dtype: bool

# %%
~s.isnull()  #null이 아니냐
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5     True
# dtype: bool

# %%
s.fillna('NUll')
# Out:
# 0     kim
# 1    NUll
# 2     lee
# 3    NUll
# 4     cho
# 5    kang
# dtype: object

# %%
from numpy import nan as NA  # NA = np.nan

# %%
s=Series([64,86,57,27,NA,57,48,np.nan,np.nan,NA])

# %%
s
# Out:
# 0    64.0
# 1    86.0
# 2    57.0
# 3    27.0
# 4     NaN
# 5    57.0
# 6    48.0
# 7     NaN
# 8     NaN
# 9     NaN
# dtype: float64

# %%
s.dropna()   # nan제거
# Out:
# 0    64.0
# 1    86.0
# 2    57.0
# 3    27.0
# 5    57.0
# 6    48.0
# dtype: float64

# %%
df={'dtt':[5,NA,NA,NA,2],'hw':[7,NA,2,8,6],'mid':[42,NA,2,31,NA],'fin':[26,NA,2,26,24]}

# %%
df=DataFrame(df)

# %%
df.dropna() #(온전한데이터 (0행)만 나옴)
# Out:
#    dtt   hw   mid   fin
# 0  5.0  7.0  42.0  26.0

# %%
df.dropna(axis=1)  # na가 열에 하나라도 있으면 열을제거
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
 df.dropna(axis=1,thresh=3)  #온전한데이터가 최소한 3개있으면 해당열선택   dtt는탈락
# Out:
#     hw   mid   fin
# 0  7.0  42.0  26.0
# 1  NaN   NaN   NaN
# 2  2.0   2.0   2.0
# 3  8.0  31.0  26.0
# 4  6.0   NaN  24.0

# %%
S=Series([2,3,4,5,1,np.nan,3,2,4,NA,NA,NA,NA,NA])

# %%
S
# Out:
# 0     2.0
# 1     3.0
# 2     4.0
# 3     5.0
# 4     1.0
# 5     NaN
# 6     3.0
# 7     2.0
# 8     4.0
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# dtype: float64

# %%
new_S=S.fillna(value=0)

# %%
new_S
# Out:
# 0     2.0
# 1     3.0
# 2     4.0
# 3     5.0
# 4     1.0
# 5     0.0
# 6     3.0
# 7     2.0
# 8     4.0
# 9     0.0
# 10    0.0
# 11    0.0
# 12    0.0
# 13    0.0
# dtype: float64

# %%
S.fillna(0,inplace=True)  #inplace=True  :  변경사항을 저장

# %%
S
# Out:
# 0     2.0
# 1     3.0
# 2     4.0
# 3     5.0
# 4     1.0
# 5     0.0
# 6     3.0
# 7     2.0
# 8     4.0
# 9     0.0
# 10    0.0
# 11    0.0
# 12    0.0
# 13    0.0
# dtype: float64

# %%
S.fillna(method='ffill',limit=1) #limit/ffill =최대몇개까지?/앞에거?뒤에거?
# Out:
# 0     2.0
# 1     3.0
# 2     4.0
# 3     5.0
# 4     1.0
# 5     1.0
# 6     3.0
# 7     2.0
# 8     4.0
# 9     4.0
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# dtype: float64

# %%
df
# Out:
#    dtt   hw   mid   fin
# 0  5.0  7.0  42.0  26.0
# 1  NaN  NaN   NaN   NaN
# 2  NaN  2.0   2.0   2.0
# 3  NaN  8.0  31.0  26.0
# 4  2.0  6.0   NaN  24.0

# %%
df.fillna(value={'dtt':0,'mid':1})  #열별로 지정가능(딕셔너리형태로)
# Out:
#    dtt   hw   mid   fin
# 0  5.0  7.0  42.0  26.0
# 1  0.0  NaN   1.0   NaN
# 2  0.0  2.0   2.0   2.0
# 3  0.0  8.0  31.0  26.0
# 4  2.0  6.0   1.0  24.0

# %%
df.fillna(value=df.mean())   #평균값으로 대체(열별 평균으로 넣는다)
# Out:
#    dtt    hw   mid   fin
# 0  5.0  7.00  42.0  26.0
# 1  3.5  5.75  25.0  19.5
# 2  3.5  2.00   2.0   2.0
# 3  3.5  8.00  31.0  26.0
# 4  2.0  6.00  25.0  24.0

# %%
df.fillna(value=df.median())   #중간값으로 넣는다
# Out:
#    dtt   hw   mid   fin
# 0  5.0  7.0  42.0  26.0
# 1  3.5  6.5  31.0  25.0
# 2  3.5  2.0   2.0   2.0
# 3  3.5  8.0  31.0  26.0
# 4  2.0  6.0  31.0  24.0

# %% [markdown]
# # 계층적 인덱스

# %%
S=Series([2,3,4,5,1,np.nan,3,2,4],index=[['stat','stat','stat','eco','eco','eco','computer','computer','computer'],[1,3,5,1,2,3,3,2,1]])

# %%
S  #인덱스가 2층으로 됌
# Out:
# stat      1    2.0
#           1    3.0
#           1    4.0
# eco       2    5.0
#           2    1.0
#           2    NaN
# computer  3    3.0
#           4    2.0
#           3    4.0
# dtype: float64

# %%
S['eco']
# Out:
# 2    5.0
# 2    1.0
# 2    NaN
# dtype: float64

# %%
S[['stat','eco']]
# Out:
# stat  1    2.0
#       2    3.0
#       3    4.0
# eco   2    5.0
#       2    1.0
#       2    NaN
# dtype: float64

# %%
S[('stat',1)]  # 1층 2층 차례로 입력
# Out:
# 2.0

# %%
S[[('stat',1),('eco',2)]]
# Out:
# stat  1    2.0
# eco   2    5.0
#       2    1.0
#       2    NaN
# dtype: float64

# %%
S[['stat','eco'][:2]]
# Out:
# stat  1    2.0
#       3    3.0
#       3    4.0
# eco   2    5.0
#       2    1.0
#       2    NaN
# dtype: float64

# %%
S.unstack()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-183-3d1f3d8988f2> in <module>
# ----> 1 S.unstack()
#
# C:\ProgramData\Anaconda3\envs\mp\lib\site-packages\pandas\core\series.py in unstack(self, level, fill_value)
#    3299         """
#    3300         from pandas.core.reshape.reshape import unstack
# -> 3301         return unstack(self, level, fill_value)
#    3302
#    3303     # ----------------------------------------------------------------------
#
# C:\ProgramData\Anaconda3\envs\mp\lib\site-packages\pandas\core\reshape\reshape.py in unstack(obj, level, fill_value)
#     394         unstacker = _Unstacker(obj.values, obj.index, level=level,
#     395                                fill_value=fill_value,
# --> 396                                constructor=obj._constructor_expanddim)
#     397         return unstacker.get_result()
#     398
#
# ...

# %%
S.unstack()     #두번쨰 인덱스를 열로보냄
# Out:
#             1    2    3    5
# computer  4.0  2.0  3.0  NaN
# eco       5.0  1.0  NaN  NaN
# stat      2.0  NaN  3.0  4.0

# %%
S.unstack().stack()  #다시 원상복귀
# Out:
# computer  1    4.0
#           2    2.0
#           3    3.0
# eco       1    5.0
#           2    1.0
# stat      1    2.0
#           3    3.0
#           5    4.0
# dtype: float64

# %%
data=np.random.binomial(n=10,p=0.6,size=40).reshape(10,4)
df=DataFrame(data,index=[['stat','stat','stat','eco','eco','eco','math','math','math','math'],[1,2,3,1,2,3,1,2,3,4]],columns=[['서울','서울','대전','대전'],['m','f','m','f']])

# %%
df
# Out:
#        서울    대전
#         m  f  m  f
# stat 1  6  7  7  6
#      2  6  5  8  6
#      3  7  6  8  6
# eco  1  6  7  4  5
#      2  4  6  7  5
#      3  4  5  6  6
# math 1  7  8  6  4
#      2  8  7  3  5
#      3  8  5  7  8
#      4  6  5  7  7

# %%
df[('서울','m')]
# Out:
# stat  1    6
#       2    6
#       3    7
# eco   1    6
#       2    4
#       3    4
# math  1    7
#       2    8
#       3    8
#       4    6
# Name: (서울, m), dtype: int32

# %%
df.loc['stat']
# Out:
#   서울    대전
#    m  f  m  f
# 1  6  7  7  6
# 2  6  5  8  6
# 3  7  6  8  6

# %%
df[1:5]
# Out:
#        서울    대전
#         m  f  m  f
# stat 2  6  5  8  6
#      3  7  6  8  6
# eco  1  6  7  4  5
#      2  4  6  7  5

# %%
df
# Out:
#        서울    대전
#         m  f  m  f
# stat 1  6  7  7  6
#      2  6  5  8  6
#      3  7  6  8  6
# eco  1  6  7  4  5
#      2  4  6  7  5
#      3  4  5  6  6
# math 1  7  8  6  4
#      2  8  7  3  5
#      3  8  5  7  8
#      4  6  5  7  7

# %%
df.loc[[('stat',1),('stat',2)]][('서울','m')]
# Out:
# stat  1    6
#       2    6
# Name: (서울, m), dtype: int32

# %%
df.swaplevel(i=1,j=0)   #인덱스 1층2층나눔
# Out:
#        서울    대전
#         m  f  m  f
# 1 stat  6  7  7  6
# 2 stat  6  5  8  6
# 3 stat  7  6  8  6
# 1 eco   6  7  4  5
# 2 eco   4  6  7  5
# 3 eco   4  5  6  6
# 1 math  7  8  6  4
# 2 math  8  7  3  5
# 3 math  8  5  7  8
# 4 math  6  5  7  7

# %%
df.swaplevel(i=1,j=0).sort_index(0)
# Out:
#        서울    대전
#         m  f  m  f
# 1 eco   6  7  4  5
#   math  7  8  6  4
#   stat  6  7  7  6
# 2 eco   4  6  7  5
#   math  8  7  3  5
#   stat  6  5  8  6
# 3 eco   4  5  6  6
#   math  8  5  7  8
#   stat  7  6  8  6
# 4 math  6  5  7  7

# %%
DataFrame(df.sum(leve))  #열별 합계
# Out:
#        0
# 서울 m  62
#    f  61
# 대전 m  63
#    f  58

# %%
df.sum(level=1)
# Out:
#    서울      대전
#     m   f   m   f
# 1  19  22  17  15
# 2  18  18  18  16
# 3  19  16  21  20
# 4   6   5   7   7

# %%
df.swaplevel(i='cls',j='dept')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\envs\mp\lib\site-packages\pandas\core\indexes\multi.py in _get_level_number(self, level)
#    1119         try:
# -> 1120             level = self.names.index(level)
#    1121         except ValueError:
#
# ValueError: 'cls' is not in list
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-9b95ba85793f> in <module>
# ----> 1 df.swaplevel(i='cls',j='dept')
#
# C:\ProgramData\Anaconda3\envs\mp\lib\site-packages\pandas\core\frame.py in swaplevel(self, i, j, axis)
#    5035         axis = self._get_axis_number(axis)
#    5036         if axis == 0:
# -> 5037             result.index = result.index.swaplevel(i, j)
#    5038         else:
# ...

# %%
df.index.names=['depth','class']

# %%
df
# Out:
#             서울    대전
#              m  f  m  f
# depth class
# stat  1      6  7  7  6
#       2      6  5  8  6
#       3      7  6  8  6
# eco   1      6  7  4  5
#       2      4  6  7  5
#       3      4  5  6  6
# math  1      7  8  6  4
#       2      8  7  3  5
#       3      8  5  7  8
#       4      6  5  7  7

# %%
df.columns.names=['area','gender']

# %%
df
# Out:
# area        서울    대전
# gender       m  f  m  f
# depth class
# stat  1      6  7  7  6
#       2      6  5  8  6
#       3      7  6  8  6
# eco   1      6  7  4  5
#       2      4  6  7  5
#       3      4  5  6  6
# math  1      7  8  6  4
#       2      8  7  3  5
#       3      8  5  7  8
#       4      6  5  7  7

# %%
data=np.random.binomial(n=10,p=0.6,size=30).reshape(10,3)
df1=DataFrame(data,columns=['v1','v2','v3'])
df1['v4']=['m','m','f','m','f','m','f','m','f','m']

# %%
df2=df1.set_index(keys=['v2','v4']).sort_index()  #변수를 인덱스로

# %%
df2
# Out:
#        v1  v3
# v2 v4
# 3  f    4   8
# 5  f    8   6
#    m    6   8
#    m    6   6
# 6  m    5   6
#    m    7   6
#    m    4   5
# 7  m    5   7
# 9  f    7   5
#    f    7   4

# %%
df2.reset_index(level='v4')  # 인덱스를 변수로
# Out:
#    v4  v1  v3
# v2
# 3   f   4   8
# 5   f   8   6
# 5   m   6   8
# 5   m   6   6
# 6   m   5   6
# 6   m   7   6
# 6   m   4   5
# 7   m   5   7
# 9   f   7   5
# 9   f   7   4

# %% [markdown]
# # 텍스트파일 읽어오기

# %%
apt=pd.read_csv('APT.csv',skiprows=7,sep=',',header=0,index_col='id',encoding='utf-8',na_values=[' ','.'])   #7줄건너뛰고 0번쨰를 헤더로쓴다.

# %% [markdown]
# * 옵션
#
#
#
#
# header=0 0번째 행을 헤더로쓴다
#
# encoding='utf-8'  : 한글은 아스키코드가아니라 utf-8로 불러와야된다.
#
# index_col='id'  : id를 인덱스로 사용하겠다
#
#
# na_values=결측처리(NaN)
# 할 문자(이경우엔 공백이랑 점을 결측처리함)

# %%
apt
# Out:
#        Area UseDistrict Option     FAR       Price
# id
# apt01   도심권  제2종 일반주거지역   풀옵션형  132.72  515.051949
# apt02   도심권  제2종 일반주거지역   풀옵션형  184.99         NaN
# apt03   NaN        상업지역    기본형     NaN  364.319535
# apt04   도심권        상업지역   풀옵션형  493.08  410.945530
# apt05   도심권       준주거지역    기본형  349.65  616.975986
# apt06   도심권  제3종 일반주거지역   풀옵션형     NaN  469.151797
# apt07   도심권  제3종 일반주거지역   풀옵션형  227.20  576.476262
# apt08   도심권        상업지역   풀옵션형  254.37  355.871886
# apt09   동북권         NaN    기본형  199.93  423.812340
# apt10   동북권  제2종 일반주거지역   풀옵션형  198.13  518.313753
# apt11   동북권  제2종 일반주거지역   풀옵션형  199.34  615.763547
# apt12   동북권  제3종 일반주거지역   풀옵션형  195.22  455.030217
# apt13   동북권  제2종 일반주거지역    기본형  199.50  460.687961
# apt14   동북권       준공업지역   풀옵션형  219.16  512.477718
# apt15   동북권  제2종 일반주거지역   풀옵션형  192.39  483.756620
# apt16   동북권  제2종 일반주거지역    기본형  198.94  489.162060
# apt17   동북권  제2종 일반주거지역    기본형  178.38  370.478698
# ...

# %%
apt=pd.read_csv('APT.csv',skiprows=10,names=['v1','v2','v3','v4','v5'],sep=',',nrows=7,header=None,index_col=0,encoding='utf-8',na_values=[' ','.'])   #7줄건너뛰고 0번쨰를 헤더로쓴다.

# %%
apt
# Out:
#         v1          v2    v3      v4          v5
# apt03  NaN        상업지역   기본형     NaN  364.319535
# apt04  도심권        상업지역  풀옵션형  493.08  410.945530
# apt05  도심권       준주거지역   기본형  349.65  616.975986
# apt06  도심권  제3종 일반주거지역  풀옵션형     NaN  469.151797
# apt07  도심권  제3종 일반주거지역  풀옵션형  227.20  576.476262
# apt08  도심권        상업지역  풀옵션형  254.37  355.871886
# apt09  동북권         NaN   기본형  199.93  423.812340

# %% [markdown]
# nrows=7 :7줄을 읽겠다.

# %%
apt[['v1','v2']]
# Out:
#         v1          v2
# apt03  NaN        상업지역
# apt04  도심권        상업지역
# apt05  도심권       준주거지역
# apt06  도심권  제3종 일반주거지역
# apt07  도심권  제3종 일반주거지역
# apt08  도심권        상업지역
# apt09  동북권         NaN

# %%
apt['Price']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\envs\mp\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Price'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-100-37ccbe103c81> in <module>
# ----> 1 apt['Price']
#
# ...

# %% [markdown]
# * 내보내기

# %%
apt2=pd.read_csv('APT.csv',skiprows=7,sep=',',nrows=7,index_col=0,encoding='utf-8',na_values=[' ','.'])   #7줄건너뛰고 0번쨰를 헤더로쓴다.

# %%
apt2.columns
# Out:
# Index(['Area', 'UseDistrict', 'Option', 'FAR', 'Price'], dtype='object')

# %%
apt2.to_csv('aptsave',sep='|',encoding='utf-8',na_rep='NULL',columns=['Area', 'UseDistrict', 'Option'])  


#na_rep=na를 뭘로처리할건지?
#columns=내보낼열선택

# %% [markdown]
# # merge

# %%
df1=DataFrame({'key':['a','b','a','c','b','c'],'v1':range(6)})  #변수가 같을경우 키랑 변수랑 같은애끼리만결합함
df2=DataFrame({'key':['a','b','d'],'v1':[3,2,4]})
print(df1,'\n',df2)
# Out:
#   key  v1
# 0   a   0
# 1   b   1
# 2   a   2
# 3   c   3
# 4   b   4
# 5   c   5
#    key  v1
# 0   a   3
# 1   b   2
# 2   d   4

# %%
pd.merge(df1,df2,on='key') #key=뭐를기준으로 조인할거냐
#c랑 ,d는 겹치지않아서 조인안함
# Out:
#   key  v1_x  v1_y
# 0   a     0     3
# 1   a     2     3
# 2   b     1     2
# 3   b     4     2

# %%
df1=DataFrame({'key':['a','b','a','c','b','c'],'v1':range(6)})  #변수가 다를경우 (key는같고 v가다름)
df2=DataFrame({'key':['a','b','d'],'v2':[3,2,4]})

# %%
pd.merge(df1,df2)
# Out:
#   key  v1  v2
# 0   a   0   3
# 1   a   2   3
# 2   b   1   2
# 3   b   4   2

# %% [markdown]
# # 이너조인=양쪽다 있는변수로만 조인함

# %%
df1=DataFrame({'key1':['a','b','a','c','b','c'],'v1':range(6)})  #변수가 다를경우 (key도 다르고 v도 다르고)
df2=DataFrame({'key2':['a','b','d'],'v2':[3,2,4]})

# %%
pd.merge(df1,df2,left_on='key1',right_on='key2')
# Out:
#   key1  v1 key2  v2
# 0    a   0    a   3
# 1    a   2    a   3
# 2    b   1    b   2
# 3    b   4    b   2

# %%
df1=DataFrame({'key1':['a','b','a','c','b','c'],'gender':['m','f','f','m','m','f'],'v1':range(6)})  #변수가 다를경우 (key도 다르고 v도 다르고)
df2=DataFrame({'key2':['a','b','d'],'sex':['f','f','m'],'v2':[3,2,4]})

# %%
df1
# Out:
#   key1 gender  v1
# 0    a      m   0
# 1    b      f   1
# 2    a      f   2
# 3    c      m   3
# 4    b      m   4
# 5    c      f   5

# %%
df2
# Out:
#   key2 sex  v2
# 0    a   f   3
# 1    b   f   2
# 2    d   m   4

# %%
pd.merge(df1,df2,left_on=['key1','gender'],right_on=['key2','sex'])  #key1==key2 이고 gender=sex 인 놈들만 결합
# Out:
#   key1 gender  v1 key2 sex  v2
# 0    b      f   1    b   f   2
# 1    a      f   2    a   f   3

# %%
pd.merge(df1,df2,left_on=['key1','gender'],right_on=['key2','sex'],how='left')   #왼쪽에있는건 전부 결합됌
# Out:
#   key1 gender  v1 key2  sex   v2
# 0    a      m   0  NaN  NaN  NaN
# 1    b      f   1    b    f  2.0
# 2    a      f   2    a    f  3.0
# 3    c      m   3  NaN  NaN  NaN
# 4    b      m   4  NaN  NaN  NaN
# 5    c      f   5  NaN  NaN  NaN

# %%
df1
# Out:
#   key1 gender  v1
# 0    a      m   0
# 1    b      f   1
# 2    a      f   2
# 3    c      m   3
# 4    b      m   4
# 5    c      f   5

# %%
pd.merge(df1,df2,left_on=['key1','gender'],right_on=['key2','sex'],how='right')  #오른쪽꺼는 무조건조인
# Out:
#   key1 gender   v1 key2 sex  v2
# 0    b      f  1.0    b   f   2
# 1    a      f  2.0    a   f   3
# 2  NaN    NaN  NaN    d   m   4

# %%
df2
# Out:
#   key2 sex  v2
# 0    a   f   3
# 1    b   f   2
# 2    d   m   4

# %%
pd.merge(df1,df2,left_on=['key1','gender'],right_on=['key2','sex'],how='outer',sort=True)
# Out:
#   key1 gender   v1 key2  sex   v2
# 0    a      f  2.0    a    f  3.0
# 1    a      m  0.0  NaN  NaN  NaN
# 2    b      f  1.0    b    f  2.0
# 3    b      m  4.0  NaN  NaN  NaN
# 4    c      f  5.0  NaN  NaN  NaN
# 5    c      m  3.0  NaN  NaN  NaN
# 6  NaN    NaN  NaN    d    m  4.0

# %%
df1=DataFrame({'key1':['a','b','a','c','b','c'],'gender':['m','f','f','m','m','f'],'v1':range(6)})  # index 사용
df2=DataFrame({'sex':['f','f','m'],'v1':[999,99,9]},index=['a','d','b'])

# %%
pd.merge(df1,df2,left_on='key1',right_index=True,how='outer',sort=True)  #라이트온대신 라이트인덱스는트루 사용
# Out:
#   key1 gender  v1_x  sex   v1_y
# 0    a      m   0.0    f  999.0
# 2    a      f   2.0    f  999.0
# 1    b      f   1.0    m    9.0
# 4    b      m   4.0    m    9.0
# 3    c      m   3.0  NaN    NaN
# 5    c      f   5.0  NaN    NaN
# 5    d    NaN   NaN    f   99.0

# %%
df1=DataFrame({'gender':['m','f','f','m','m','f'],'v1':range(6)},index=['a','b','a','c','b','c'])  # index 사용
df2=DataFrame({'sex':['f','f','m'],'v1':[999,99,9]},index=['a','d','b'])

# %%
pd.merge(df1,df2,left_index=True,right_index=True,how='outer',sort=True)
# Out:
#   gender  v1_x  sex   v1_y
# a      m   0.0    f  999.0
# a      f   2.0    f  999.0
# b      f   1.0    m    9.0
# b      m   4.0    m    9.0
# c      m   3.0  NaN    NaN
# c      f   5.0  NaN    NaN
# d    NaN   NaN    f   99.0

# %% [markdown]
# #suffix = 접미어 v1_x,v1_y에서 _x,_y바꿀수있음

# %%
df1.join(df2,lsuffix='_left',rsuffix='_right')
# Out:
#   gender  v1_left  sex  v1_right
# a      m        0    f     999.0
# a      f        2    f     999.0
# b      f        1    m       9.0
# b      m        4    m       9.0
# c      m        3  NaN       NaN
# c      f        5  NaN       NaN

# %% [markdown]
# * 축에따라 데이터 붙이기

# %%
s1=Series([2,5,3,6,4,1],index=['a','b','d','c','e','f'])
s2=Series([12,45,23],index=['a','b','e'])
s3=Series([999,99,9,9999],index=['a','b','e','d'])

# %%
pd.concat([s1,s2,s3],axis=1)  #axis=1 ,열결합
# Out:
# C:\ProgramData\Anaconda3\envs\mp\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#    0     1       2
# a  2  12.0   999.0
# b  5  45.0    99.0
# c  6   NaN     NaN
# d  3   NaN  9999.0
# e  4  23.0     9.0
# f  1   NaN     NaN

# %%
pd.concat([s1,s2,s3],axis=1,join='inner')  # how 대신 join
# Out:
#    0   1    2
# a  2  12  999
# b  5  45   99
# e  4  23    9

# %%
print(s1,'\n',s2,'\n',s3)
# Out:
# a    2
# b    5
# d    3
# c    6
# e    4
# f    1
# dtype: int64
#  a    12
# b    45
# e    23
# dtype: int64
#  a     999
# b      99
# e       9
# d    9999
# dtype: int64

# %%
pd.concat([s1,s2,s3],axis=1,join_axes=[['a','e']])
# Out:
#    0   1    2
# a  2  12  999
# e  4  23    9

# %%
pd.concat([s1,s2,s3],axis=0,keys=['aa','bb','cc'])  #계층 인덱스 axis 주의
# Out:
# aa  a       2
#     b       5
#     d       3
#     c       6
#     e       4
#     f       1
# bb  a      12
#     b      45
#     e      23
# cc  a     999
#     b      99
#     e       9
#     d    9999
# dtype: int64

# %%
pd.concat([s1,s2,s3],axis=1,keys=['aa','bb','cc'])  # 키로 컬럼 지정
# Out:
# C:\ProgramData\Anaconda3\envs\mp\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#    aa    bb      cc
# a   2  12.0   999.0
# b   5  45.0    99.0
# c   6   NaN     NaN
# d   3   NaN  9999.0
# e   4  23.0     9.0
# f   1   NaN     NaN

# %%
df1=DataFrame(np.arange(12).reshape(3,4),index=['a','b','d'],columns=['v1','v2','v3','v4'])
df2=DataFrame(np.arange(8).reshape(2,4),index=['b','c'],columns=['v1','x2','x3','x4'])       # v1

# %%
df1
# Out:
#    v1  v2  v3  v4
# a   0   1   2   3
# b   4   5   6   7
# d   8   9  10  11

# %%
df2
# Out:
#    v1  x2  x3  x4
# b   0   1   2   3
# d   4   5   6   7

# %%
pd.concat([df1,df2],axis=0)  #변수명이 다른경우의 결합 , 같은변수명이있으면 밑으로(axis=0)으로 가사ㅓ 붙는다
# Out:
# C:\ProgramData\Anaconda3\envs\mp\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#    v1   v2    v3    v4   x2   x3   x4
# a   0  1.0   2.0   3.0  NaN  NaN  NaN
# b   4  5.0   6.0   7.0  NaN  NaN  NaN
# d   8  9.0  10.0  11.0  NaN  NaN  NaN
# b   0  NaN   NaN   NaN  1.0  2.0  3.0
# d   4  NaN   NaN   NaN  5.0  6.0  7.0

# %%
pd.concat([df1,df2],axis=0,ignore_index=True)  #ignore_index=True 기존인덱스 무시하고 그냥 순서 인덱스로 재배치함
# Out:
# C:\ProgramData\Anaconda3\envs\mp\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#    v1   v2    v3    v4   x2   x3   x4
# 0   0  1.0   2.0   3.0  NaN  NaN  NaN
# 1   4  5.0   6.0   7.0  NaN  NaN  NaN
# 2   8  9.0  10.0  11.0  NaN  NaN  NaN
# 3   0  NaN   NaN   NaN  1.0  2.0  3.0
# 4   4  NaN   NaN   NaN  5.0  6.0  7.0

# %%
pd.concat([df1,df2],axis=1)  #인덱스가 b만겹친다.
# Out:
# C:\ProgramData\Anaconda3\envs\mp\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#     v1   v2    v3    v4   v1   x2   x3   x4
# a  0.0  1.0   2.0   3.0  NaN  NaN  NaN  NaN
# b  4.0  5.0   6.0   7.0  0.0  1.0  2.0  3.0
# c  NaN  NaN   NaN   NaN  4.0  5.0  6.0  7.0
# d  8.0  9.0  10.0  11.0  NaN  NaN  NaN  NaN

# %%
pd.concat([df1,df2],axis=0,keys=['df1','df2']) #계층인덱스로 잡힘
# Out:
# C:\ProgramData\Anaconda3\envs\mp\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#        v1   v2    v3    v4   x2   x3   x4
# df1 a   0  1.0   2.0   3.0  NaN  NaN  NaN
#     b   4  5.0   6.0   7.0  NaN  NaN  NaN
#     d   8  9.0  10.0  11.0  NaN  NaN  NaN
# df2 b   0  NaN   NaN   NaN  1.0  2.0  3.0
#     c   4  NaN   NaN   NaN  5.0  6.0  7.0

# %%
pd.concat([df1,df2],axis=1,keys=['df1','df2'])
# Out:
# C:\ProgramData\Anaconda3\envs\mp\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#    df1                   df2
#     v1   v2    v3    v4   v1   x2   x3   x4
# a  0.0  1.0   2.0   3.0  NaN  NaN  NaN  NaN
# b  4.0  5.0   6.0   7.0  0.0  1.0  2.0  3.0
# c  NaN  NaN   NaN   NaN  4.0  5.0  6.0  7.0
# d  8.0  9.0  10.0  11.0  NaN  NaN  NaN  NaN

# %% [markdown]
# * 중복자료 체크

# %%
df1=DataFrame({'gender':['m','f','m','m','f'],'name':['kim','lee','lee','lee','kim'],'x1':[2,3,2,2,3]},index=['a','b','d','e','c'])

# %%
df1
# Out:
#   gender name  x1
# a      m  kim   2
# b      f  lee   3
# d      m  lee   2
# e      m  lee   2
# c      f  kim   3

# %%
print(df1.duplicated())  #디폴트로 첫번쨰꺼랑 모든원소가 같은가?
# Out:
# a    False
# b    False
# d    False
# e     True
# c    False
# dtype: bool

# %%
print(df1.duplicated(subset='name'))
# Out:
# a    False
# b    False
# d     True
# e     True
# c     True
# dtype: bool

# %%
print(df1.duplicated(subset=['gender','name'],keep='last'))   #뒤를남기고 앞에거 지움
# Out:
# a    False
# b    False
# d     True
# e    False
# c    False
# dtype: bool

# %%
df.drop_duplicates(subset=['gender','name'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-241-1dcac07777a8> in <module>
# ----> 1 df.drop_duplicates(subset=['gender','name'])
#
# C:\ProgramData\Anaconda3\envs\mp\lib\site-packages\pandas\core\frame.py in drop_duplicates(self, subset, keep, inplace)
#    4628
#    4629         inplace = validate_bool_kwarg(inplace, 'inplace')
# -> 4630         duplicated = self.duplicated(subset, keep=keep)
#    4631
#    4632         if inplace:
#
# C:\ProgramData\Anaconda3\envs\mp\lib\site-packages\pandas\core\frame.py in duplicated(self, subset, keep)
#    4681         diff = Index(subset).difference(self.columns)
#    4682         if not diff.empty:
# -> 4683             raise KeyError(diff)
#    4684
#    4685         vals = (col.values for name, col in self.iteritems()
#
# KeyError: Index(['gender', 'name'], dtype='object')

# %% [markdown]
# # mapping 이용해 데이터 변형

# %% [markdown]
# 문자자료를 숫자로 저장하고 다시 문자로바꿈(이게 오타확률도적고 편하니까)

# %%
df=DataFrame({'name':['kim','lee','bae','cho','kang'],'sex':[3,2,4,1,1],'home':['마포',np.nan,'처인','용산','종로'],'income':[250,195,325,210,np.inf]})
num_to_str={1:'남',2:'여'}
to_city={'마포':'서울','용산':'서울','종로':'서울','수지':'용인','처인':'용인'}

# %%
df['gender']=df['sex'].map(num_to_str)

# %%
# Out:
#    name  sex home  income gender
# 0   kim    1   마포     250      남
# 1   lee    2   수지     195      여
# 2   bae    2   처인     325      여
# 3   cho    1   용산     210      남
# 4  kang    1   종로     274      남

# %%
df['city']=df['home'].map(to_city)

# %%
df
# Out:
#    name  sex home  income
# 0   kim    3   마포   250.0
# 1   lee    2  NaN   195.0
# 2   bae    4   처인   325.0
# 3   cho    1   용산   210.0
# 4  kang    1   종로     inf

# %%
df.replace([np.nan,3,4],[9999,22,33])   #(탐색할데이터),(변환할 데이터)
# Out:
#    name  sex  home  income
# 0   kim   22    마포   250.0
# 1   lee    2  9999   195.0
# 2   bae   33    처인   325.0
# 3   cho    1    용산   210.0
# 4  kang    1    종로     inf

# %%
df.replace({'sex':{3:1,4:2},'income':{9999:np.nan,np.inf:np.nan}})  #{'변수':{'찾을값':바꿀값}}  사전안에 사전형태
# Out:
#    name  sex home  income
# 0   kim    1   마포   250.0
# 1   lee    2  NaN   195.0
# 2   bae    2   처인   325.0
# 3   cho    1   용산   210.0
# 4  kang    1   종로     NaN
